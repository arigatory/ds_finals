# %% [markdown]
# Привет! Меня зовут Исмаилов Исмаил, я буду проверять твой проект :) Можешь обращаться ко мне на «ты». Если тебе комфортно, то и я буду к тебе так обращаться, если нет, то обязательно скажи об этом.
#
# Пожалуйста, не удаляй мои комментарии, которые я буду оставлять в работе. Это особенно поможет, если твои проекты будут отправлены на повторную проверку. При повторных проверках у комментариев будут приписки: "Вторая итерация", "Третья итерация" и т.д.
#
# Ты тоже можешь реагировать на мои комментарии, но в таком случае постарайся, чтобы твои комментарии отличались от моих: например, выделяй их своим любимым цветом — так у нас не возникнет путаницы :)
#
# Кстати, про цвета! Мои комментарии будут в следующей цветовой гамме: зелеными, желтыми и красными. Например:
#
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 </b>
#
# В случае, если решение на отдельном шаге является полностью правильным. </div>
#
# <div class="alert-warning">
# <b>Комментарий ревьюера 💡</b>
#
# В случае, если решение может стать еще лучше с некоторыми корректировками </div>
#
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# В случае, если решение какого-то шага требует значительных изменений. Проект не может быть принят с первого раза, если ревью содержит комментарии, помеченные этим цветом </div>

# %% [markdown]
# ## Шаг. Откройте файл с данными и изучите общую информацию

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Нет необходимого вступления в проект: нужно рассказать, что за данные у тебя имеются, что вообще стоит делать, какие цели и задачи, что желаешь получить. Представь, что показываешь проект бизнесу / заказчику: заказчик не поймет даже, где оказался, потому что в проекте нет и названия, поэтому нужно стороннего читателя вводить в курс дела </div>

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Не знал, что нужно делать вступление)
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 Вторая итерация </b>
#
# Нужно)

# %% [markdown]
# # Вступление
# Данное исследование проводится в интернет-магазине «Стримчик», который занимается продажей компьютерных игр по всему миру. Цель исследования заключается в выявлении определяющих успешность игр закономерностей на основе исторических данных о продажах, оценках пользователей и экспертов, жанрах, платформах и возрастных рейтингах игр. Исследование необходимо для того, чтобы сделать ставку на потенциально популярный продукт и спланировать эффективные рекламные кампании. Данные, на которых будет проводиться исследование, относятся к периоду до 2016 года, а задача заключается в том, чтобы на их основе разработать принцип работы с данными для прогнозирования продаж на будущее. В данных присутствует аббревиатура ESRB, которая определяет возрастной рейтинг компьютерных игр.

# %%
import pandas as pd
df = pd.read_csv('/datasets/games.csv')
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ## Шаг. Подготовьте данные

# %% [markdown]
# ### Замените названия столбцов (приведите к нижнему регистру);

# %%
# старая неоптимальная версия: df = df.rename(columns={k:k.lower() for k in list(df.columns)})
df.columns = df.columns.str.lower()

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера 💡 </b>
#
# Неоптимально, используй str.lower к df.columns

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Спасибо, учел замечание
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Итак, в таблице 11 столбцов. Тип данных во всех столбцах — `object` или `float64`.
#
# Согласно документации к данным:
# * `name` — название игры;
# * `platform` — платформа;
# * `year_of_release` — год выпуска;
# * `genre` — жанр игры;
# * `na_sales` — продажи в Северной Америке (миллионы проданных копий);
# * `eu_sales` — продажи в Европе (миллионы проданных копий);
# * `jp_sales` — продажи в Японии (миллионы проданных копий);
# * `other_sales` — продажи в других странах (миллионы проданных копий);
# * `critic_score` —  оценка критиков (максимум 100);
# * `user_score` — оценка пользователей (максимум 10);
# * `rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Количество значений в столбцах различается. Значит, в данных есть пропущенные значения.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍</b>
#
# Хороший первичный обзор данных

# %% [markdown]
# ### Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;

# %% [markdown]
# год удобнее хранить в виде целого числа, пропуски заполним нулям

# %%
df['year_of_release'] = df['year_of_release'].fillna(0)
df['year_of_release'] = df['year_of_release'].astype(int)

# %% [markdown]
# оценки критиков приведем к шкале от 0 до 10, чтобы удобнее сравнивать с пользователями

# %%
df['critic_score'] = df['critic_score']/10

# %% [markdown]
# аббревиатура 'tbd' означает, что значение еще не определено, мы заменим значение на None так как в данном контексте это одно и тоже, после этого приведем тип к float, чтобы с оценками работать, как с числами

# %%
df.loc[df['user_score'] == 'tbd','user_score'] = None
df['user_score'] = df['user_score'].astype(float)

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 </b>
#
# Верное решение обработать tbd, как nan

# %% [markdown]
# изучим столбец с рейтингом ESRB

# %%
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Итак, в столбце 10 различных значений. Тип данных во всех столбцах — `object`.
#
# Расшифруем значения, согласно документации из интернета:
# * `E` — «**Для всех**»: Содержание вполне подходит для возрастной категории от 6 лет. Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Первой игрой, которая получила данный рейтинг, стала The Simpsons Cartoon Studio, выпущенная в 1996 году. Первоначально "K-A" ("Kids to Adults");
# * `nan` — нет информации;
# * `M` — «**Для взрослых**»: Материалы игры не подходят для лиц младше 17 лет. Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории;
# * `T` — «**Подросткам**»: Игра подходит для лиц от 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики;
# * `E10+` —  «**Для всех от 10 лет и старше**»: Проекты с данным рейтингом могут содержать или немного больше мультипликационного или мягкого насилия, или несколько откровенные сцены, или минимальное количество крови. Рейтинг был принят ESRB 2 марта 2005 года. Первой игрой, которая получила данный рейтинг, стала Donkey Kong: Jungle Beat;
# * `None` — нет информации;
# * `K-A` — Старое обозначение для рейтинга "**E**";
# * `AO` — «**Только для взрослых**»: Содержание игры только для взрослых старше 18 лет. Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое, а также сцены с обнажением. Большинство таких игр предназначено для персональных компьютеров под управлением Microsoft Windows и Apple Macintosh. Рейтинг «Только для взрослых» является предметом многочисленных дискуссий, так как накладывает серьёзные ограничения на продажи игры. Первой игрой, которая получила данный рейтинг, стала The Joy of Sex, выпущенная в 1993 году;
# * `EC` —  «**Для детей младшего возраста**»: Игра подходит для детей от 3 лет и не содержит материалов, которые родители могли бы счесть неподходящими. Продукты, получившие данный рейтинг, изначально разрабатываются для детей и обычно представляют собой развивающие игры. Некоторые усложнённые развивающие игры могут иметь рейтинг «Everyone»;
# * `RP` — «**Рейтинг ожидается**»: Продукт был отправлен в ESRB и ожидает присвоения рейтинга. Данный логотип используется только на рекламных презентациях и в демо-версиях игр до официальной даты выпуска в продажу.

# %% [markdown]
# Прежде чем заменим K-A на E, посмотрим, что это за игры

# %%
df.loc[df['rating']=='K-A']
# Out:
#                      name platform  year_of_release     genre  na_sales  \
# 656        Theme Hospital       PC             1997  Strategy      2.30
# 903    PaRappa The Rapper       PS             1996      Misc      0.26
# 16681             Worms 2       PC             1997  Strategy      0.00
#
#        eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 656        0.10      0.00         0.00           NaN         9.0    K-A
# 903        0.16      1.46         0.03           9.2         7.4    K-A
# 16681      0.01      0.00         0.00           NaN         8.1    K-A

# %% [markdown]
# Действительно, игры старые, 1997 года выпуска. Заменим K-A на E, так как это одно и тоже

# %%
df.loc[df['rating']=='K-A', 'rating'] = 'E'

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45           7.6         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29           8.2         8.3      E
# 3     10.93      3.28         2.95           8.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера 💡</b>
#
# Не следует выводить всю таблицу целиком. Используй .head, .tail, .sample

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Думал, что нет разницы, так как все равно она не вся выводится
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 Вторая итерация </b>
#
# Не совсем так, это влияет на память

# %% [markdown]
# ### Обработайте пропуски при необходимости:

# %% [markdown]
# Посмотрим на количество уникальных значений в каждой колонке

# %%
df['name'].value_counts()
# Out:
# Need for Speed: Most Wanted                              12
# FIFA 14                                                   9
# LEGO Marvel Super Heroes                                  9
# Madden NFL 07                                             9
# Ratatouille                                               9
#                                                          ..
# Phantasy Star Online Episode III: C.A.R.D. Revolution     1
# Namco Museum 64                                           1
# Xbox Music Mixer                                          1
# Deadliest Catch: Alaskan Storm                            1
# Mario Kart Wii                                            1
# Name: name, Length: 11559, dtype: int64

# %%
df[df['name']=='Need for Speed: Most Wanted']
# Out:
#                               name platform  year_of_release   genre  \
# 253    Need for Speed: Most Wanted      PS2             2005  Racing
# 523    Need for Speed: Most Wanted      PS3             2012  Racing
# 1190   Need for Speed: Most Wanted     X360             2012  Racing
# 1591   Need for Speed: Most Wanted     X360             2005  Racing
# 1998   Need for Speed: Most Wanted       XB             2005  Racing
# 2048   Need for Speed: Most Wanted      PSV             2012  Racing
# 3581   Need for Speed: Most Wanted       GC             2005  Racing
# 5972   Need for Speed: Most Wanted       PC             2005  Racing
# 6273   Need for Speed: Most Wanted     WiiU             2013  Racing
# 6410   Need for Speed: Most Wanted       DS             2005  Racing
# 6473   Need for Speed: Most Wanted      GBA             2005  Racing
# 11715  Need for Speed: Most Wanted       PC             2012  Racing
#
# ...

# %%
df[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %%
# df = df[~df['name'].isna()]
# df.reset_index(drop=True, inplace=True)

df.dropna(subset=['name'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Видим, что Need for Speed предсавлена чаще всего для разных платформ. Но в целом в столбце с именами всего 2 пропуска, которые можно просто удалить

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера 💡</b>
#
# Легче через dropna

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Почему-то такой вариант выводит предупреждение SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 Вторая итерация </b>
#
# Часто бывает такое, когда видоизменяешь датафрейм, можешь глянуть, что он значит

# %% [markdown]
# Посмотрим на уникальные значения для платформы

# %%
df['platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: platform, dtype: int64

# %% [markdown]
# Попробуем расшифровать значения с помощью интернета http://vgmpf.com/Wiki/index.php/List_of_Platform_Abbreviations_(A-N)

# %% [markdown]
# Здесь нельзя работать с сетевыми запросами, поэтому скопирую сюда html код таблиц с расшифровкой платформ (сразу прошу прощения за скролл)

# %%
table_a_n = '''
<table class="wikitable">
<tbody><tr>
<th> Abbr.
</th>
<th> Icon
</th>
<th> Platform Name
</th>
<th> Count
</th>
<th> Category
</th>
<th> Notes
</th></tr>
<tr>
<td> <a href="/Wiki/index.php?title=32X&amp;action=edit&amp;redlink=1" class="new" title="32X (page does not exist)">32X</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-
games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Android_OS&amp;action=edit&amp;redlink=1" class="new" title="Android OS (page does not exist)">AND</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_AND.png" class="image"><img alt="Platform - AND.png" src="/Wiki/images/thumb/4/41/Platform_-_AND.png/32px-Platform_-_AND.png" width="32" height="32" srcset="/Wiki/images/thumb/4/41/Platform_-_AND.png/48px-Platform_-_AND.png 1.5x, /Wiki/images/thumb/4/41/Platform_-_AND.png/64px-Platform_-_AND.png 2x"></a>
</td>
<td> Android OS
</td>
<td> 1
</td>
<td> <a href="/Wiki/index.php?title=Category:Android_Games" title="Category:Android Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Arcade" title="Arcade">ARC</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_ARC.png" class="image"><img alt="Platform - ARC.png" src="/Wiki/images/thumb/1/10/Platform_-_ARC.png/32px-Platform_-_ARC.png" width="32" height="32" srcset="/Wiki/images/thumb/1/10/Platform_-_ARC.png/48px-Platform_-_ARC.png 1.5x, /Wiki/images/thumb/1/10/Platform_-_ARC.png/64px-Platform_-_ARC.png 2x"></a>
</td>
<td> Arcade
</td>
<td> 32
</td>
<td> <a href="/Wiki/index.php?title=Category:Arcade_Games" title="Category:Arcade Games">Category</a>
</td>
<td> Mention sound chip in game page.
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Archimedes&amp;action=edit&amp;redlink=1" class="new" title="Archimedes (page does not exist)">ARCH</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_ARCH.png" class="image"><img alt="Platform - ARCH.png" src="/Wiki/images/thumb/1/1c/Platform_-_ARCH.png/32px-Platform_-_ARCH.png" width="32" height="32" srcset="/Wiki/images/thumb/1/1c/Platform_-_ARCH.png/48px-Platform_-_ARCH.png 1.5x, /Wiki/images/thumb/1/1c/Platform_-_ARCH.png/64px-Platform_-_ARCH.png 2x"></a>
</td>
<td> Acorn Archimedes
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Archimedes_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Archimedes Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Atari_ST" title="Atari ST">AST</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_AST.png" class="image"><img alt="Platform - AST.png" src="/Wiki/images/thumb/7/7d/Platform_-_AST.png/32px-Platform_-_AST.png" width="32" height="32" srcset="/Wiki/images/thumb/7/7d/Platform_-_AST.png/48px-Platform_-_AST.png 1.5x, /Wiki/images/thumb/7/7d/Platform_-_AST.png/64px-Platform_-_AST.png 2x"></a>
</td>
<td> Atari ST
</td>
<td> 15
</td>
<td> <a href="/Wiki/index.php?title=Category:Atari_ST_Games" title="Category:Atari ST Games">Category</a>
</td>
<td> Mention specific platform (ST, STE, TT, MEGA STE)
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Bally_Astrocade&amp;action=edit&amp;redlink=1" class="new" title="Bally Astrocade (page does not exist)">BA</a>
</td>
<td>
</td>
<td> Bally Astrocade
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Bally_Astrocade_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Bally Astrocade Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=BlackBerry&amp;action=edit&amp;redlink=1" class="new" title="BlackBerry (page does not exist)">BB</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_BB.png" class="image"><img alt="Platform - BB.png" src="/Wiki/images/thumb/f/f1/Platform_-_BB.png/32px-Platform_-_BB.png" width="32" height="32" srcset="/Wiki/images/thumb/f/f1/Platform_-_BB.png/48px-Platform_-_BB.png 1.5x, /Wiki/images/thumb/f/f1/Platform_-_BB.png/64px-Platform_-_BB.png 2x"></a>
</td>
<td> BlackBerry
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:BlackBerry_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:BlackBerry Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=BBC_Micro" title="BBC Micro">BBC</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Famicom_Disk_System" title="Famicom Disk System">FDS</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_FDS.png" class="image"><img alt="Platform - FDS.png" src="/Wiki/images/thumb/1/1e/Platform_-_FDS.png/32px-Platform_-_FDS.png" width="32" height="32" srcset="/Wiki/images/thumb/1/1e/Platform_-_FDS.png/48px-Platform_-_FDS.png 1.5x, /Wiki/images/thumb/1/1e/Platform_-_FDS.png/64px-Platform_-_FDS.png 2x"></a>
</td>
<td> Nintendo Famicom Disk System
</td>
<td> 23
</td>
<td> <a href="/Wiki/index.php?title=Category:Famicom_Disk_System_Games" title="Category:Famicom Disk System Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Fire_OS&amp;action=edit&amp;redlink=1" class="new" title="Fire OS (page does not exist)">FIRE</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_FIRE.png" class="image"><img alt="Platform - FIRE.png" src="/Wiki/images/thumb/3/3a/Platform_-_FIRE.png/32px-Platform_-_FIRE.png" width="32" height="32" srcset="/Wiki/images/thumb/3/3a/Platform_-_FIRE.png/48px-Platform_-_FIRE.png 1.5x, /Wiki/images/thumb/3/3a/Platform_-_FIRE.png/64px-Platform_-_FIRE.png 2x"></a>
</td>
<td> Amazon Fire OS
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Fire_OS_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Fire OS Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=FM-7&amp;action=edit&amp;redlink=1" class="new" title="FM-7 (page does not exist)">FM7</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_FM7.png" class="image"><img alt="Platform - FM7.png" src="/Wiki/images/thumb/4/4f/Platform_-_FM7.png/32px-Platform_-_FM7.png" width="32" height="32" srcset="/Wiki/images/thumb/4/4f/Platform_-_FM7.png/48px-Platform_-_FM7.png 1.5x, /Wiki/images/thumb/4/4f/Platform_-_FM7.png/64px-Platform_-_FM7.png 2x"></a>
</td>
<td> Fujitsu FM-7
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:FM-7_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:FM-7 Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=FM_Towns&amp;action=edit&amp;redlink=1" class="new" title="FM Towns (page does not exist)">FMT</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_FMT.png" class="image"><img alt="Platform - FMT.png" src="/Wiki/images/thumb/7/77/Platform_-_FMT.png/32px-Platform_-_FMT.png" width="32" height="32" srcset="/Wiki/images/thumb/7/77/Platform_-_FMT.png/48px-Platform_-_FMT.png 1.5x, /Wiki/images/thumb/7/77/Platform_-_FMT.png/64px-Platform_-_FMT.png 2x"></a>
</td>
<td> Fujitsu FM Towns
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:FM_Towns_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:FM Towns Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Game_Boy" title="Game Boy">GB</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_GB.png" class="image"><img alt="Platform - GB.png" src="/Wiki/images/thumb/7/70/Platform_-_GB.png/32px-Platform_-_GB.png" width="32" height="32" srcset="/Wiki/images/thumb/7/70/Platform_-_GB.png/48px-Platform_-_GB.png 1.5x, /Wiki/images/thumb/7/70/Platform_-_GB.png/64px-Platform_-_GB.png 2x"></a>
</td>
<td> Nintendo Game Boy
</td>
<td> 36
</td>
<td> <a href="/Wiki/index.php?title=Category:Game_Boy_Games" title="Category:Game Boy Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Game_Boy_Advance&amp;action=edit&amp;redlink=1" class="new" title="Game Boy Advance (page does not exist)">GBA</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-
a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_LYNX.png" class="image"><img alt="Platform - LYNX.png" src="/Wiki/images/thumb/5/57/Platform_-_LYNX.png/32px-Platform_-_LYNX.png" width="32" height="32" srcset="/Wiki/images/thumb/5/57/Platform_-_LYNX.png/48px-Platform_-_LYNX.png 1.5x, /Wiki/images/thumb/5/57/Platform_-_LYNX.png/64px-Platform_-_LYNX.png 2x"></a>
</td>
<td> Atari Lynx
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Lynx_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Lynx Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Macintosh" title="Macintosh">MAC</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_MAC.png" class="image"><img alt="Platform - MAC.png" src="/Wiki/images/thumb/d/dc/Platform_-_MAC.png/32px-Platform_-_MAC.png" width="32" height="32" srcset="/Wiki/images/thumb/d/dc/Platform_-_MAC.png/48px-Platform_-_MAC.png 1.5x, /Wiki/images/thumb/d/dc/Platform_-_MAC.png/64px-Platform_-_MAC.png 2x"></a>
</td>
<td> Apple Macintosh
</td>
<td> 17
</td>
<td> <a href="/Wiki/index.php?title=Category:Macintosh_Games" title="Category:Macintosh Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Marty&amp;action=edit&amp;redlink=1" class="new" title="Marty (page does not exist)">MART</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_MART.png" class="image"><img alt="Platform - MART.png" src="/Wiki/images/thumb/e/e6/Platform_-_MART.png/32px-Platform_-_MART.png" width="32" height="32" srcset="/Wiki/images/thumb/e/e6/Platform_-_MART.png/48px-Platform_-_MART.png 1.5x, /Wiki/images/thumb/e/e6/Platform_-_MART.png/64px-Platform_-_MART.png 2x"></a>
</td>
<td> Fujitsu FM Towns Marty
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Games" title="Category:Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Sega_CD" class="mw-redirect" title="Sega CD">MCD</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_MCD.png" class="image"><img alt="Platform - MCD.png" src="/Wiki/images/thumb/7/77/Platform_-_MCD.png/32px-Platform_-_MCD.png" width="32" height="32" srcset="/Wiki/images/thumb/7/77/Platform_-_MCD.png/48px-Platform_-_MCD.png 1.5x, /Wiki/images/thumb/7/77/Platform_-_MCD.png/64px-Platform_-_MCD.png 2x"></a>
</td>
<td> Sega Mega CD
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Mega_CD_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Mega CD Games (page does not exist)">Category</a>
</td>
<td> Use for non-US releases of Sega CD.
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=MSX" title="MSX">MSX</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_MSX.png" class="image"><img alt="Platform - MSX.png" src="/Wiki/images/thumb/a/ad/Platform_-_MSX.png/32px-Platform_-_MSX.png" width="32" height="32" srcset="/Wiki/images/thumb/a/ad/Platform_-_MSX.png/48px-Platform_-_MSX.png 1.5x, /Wiki/images/thumb/a/ad/Platform_-_MSX.png/64px-Platform_-_MSX.png 2x"></a>
</td>
<td>
</td>
<td> 7
</td>
<td> <a href="/Wiki/index.php?title=Category:MSX_Games" title="Category:MSX Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=MSX2" title="MSX2">MSX2</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_MSX2.png" class="image"><img alt="Platform - MSX2.png" src="/Wiki/images/thumb/9/94/Platform_-_MSX2.png/32px-Platform_-_MSX2.png" width="32" height="32" srcset="/Wiki/images/thumb/9/94/Platform_-_MSX2.png/48px-Platform_-_MSX2.png 1.5x, /Wiki/images/thumb/9/94/Platform_-_MSX2.png/64px-Platform_-_MSX2.png 2x"></a>
</td>
<td> MSX2, MSX2+, MSX TurboR
</td>
<td> 7
</td>
<td> <a href="/Wiki/index.php?title=Category:MSX2_Games" title="Category:MSX2 Games">Category</a>
</td>
<td> Mention specific platform in game page.
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=
a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_NGCD.png" class="image"><img alt="Platform - NGCD.png" src="/Wiki/images/thumb/6/61/Platform_-_NGCD.png/32px-Platform_-_NGCD.png" width="32" height="32" srcset="/Wiki/images/thumb/6/61/Platform_-_NGCD.png/48px-Platform_-_NGCD.png 1.5x, /Wiki/images/thumb/6/61/Platform_-_NGCD.png/64px-Platform_-_NGCD.png 2x"></a>
</td>
<td> SNK Neo Geo CD
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Neo_Geo_CD_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Neo Geo CD Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Neo_Geo_Pocket&amp;action=edit&amp;redlink=1" class="new" title="Neo Geo Pocket (page does not exist)">NGP</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_NGP.png" class="image"><img alt="Platform - NGP.png" src="/Wiki/images/thumb/6/67/Platform_-_NGP.png/32px-Platform_-_NGP.png" width="32" height="32" srcset="/Wiki/images/thumb/6/67/Platform_-_NGP.png/48px-Platform_-_NGP.png 1.5x, /Wiki/images/thumb/6/67/Platform_-_NGP.png/64px-Platform_-_NGP.png 2x"></a>
</td>
<td> SNK Neo Geo Pocket
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Neo_Geo_Pocket_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Neo Geo Pocket Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Neo_Geo_Pocket_Color&amp;action=edit&amp;redlink=1" class="new" title="Neo Geo Pocket Color (page does not exist)">NGPC</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_NGPC.png" class="image"><img alt="Platform - NGPC.png" src="/Wiki/images/thumb/e/ef/Platform_-_NGPC.png/32px-Platform_-_NGPC.png" width="32" height="32" srcset="/Wiki/images/thumb/e/ef/Platform_-_NGPC.png/48px-Platform_-_NGPC.png 1.5x, /Wiki/images/thumb/e/ef/Platform_-_NGPC.png/64px-Platform_-_NGPC.png 2x"></a>
</td>
<td> SNK Neo Geo Pocket Color
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Neo_Geo_Pocket_Color_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Neo Geo Pocket Color Games (page does not exist)">Category</a>
</td>
<td>
</td></tr></tbody></table>
'''

# %%
table_o_z = '''
<table class="wikitable">
<tbody><tr>
<th> Abbr.
</th>
<th> Icon
</th>
<th> Platform Name
</th>
<th> Count
</th>
<th> Category
</th>
<th> Notes
</th></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Odyssey_2&amp;action=edit&amp;redlink=1" class="new" title="Odyssey 2 (page does not exist)">ODY2</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_ODY2.png" class="image"><img alt="Platform - ODY2.png" src="/Wiki/images/thumb/f/f7/Platform_-_ODY2.png/32px-Platform_-_ODY2.png" width="32" height="32" srcset="/Wiki/images/thumb/f/f7/Platform_-_ODY2.png/48px-Platform_-_ODY2.png 1.5x, /Wiki/images/thumb/f/f7/Platform_-_ODY2.png/64px-Platform_-_ODY2.png 2x"></a>
</td>
<td> Magnavox Odyssey 2
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Odyssey_2_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Odyssey 2 Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Ouya&amp;action=edit&amp;redlink=1" class="new" title="Ouya (page does not exist)">OUYA</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_OUYA.png" class="image"><img alt="Platform - OUYA.png" src="/Wiki/images/thumb/f/f0/Platform_-_OUYA.png/32px-Platform_-_OUYA.png" width="32" height="32" srcset="/Wiki/images/thumb/f/f0/Platform_-_OUYA.png/48px-Platform_-_OUYA.png 1.5x, /Wiki/images/thumb/f/f0/Platform_-_OUYA.png/64px-Platform_-_OUYA.png 2x"></a>
</td>
<td> Ouya
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Ouya_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Ouya Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Palm_OS&amp;action=edit&amp;redlink=1" class="new" title="Palm OS (page does not exist)">PALM</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PALM.png" class="image"><img alt="Platform - PALM.png" src="/Wiki/images/thumb/e/e1/Platform_-_PALM.png/32px-Platform_-_PALM.png" width="32" height="32" srcset="/Wiki/images/thumb/e/e1/Platform_-_PALM.png/48px-Platform_-_PALM.png 1.5x, /Wiki/images/thumb/e/e1/Platform_-_PALM.png/64px-Platform_-_PALM.png 2x"></a>
</td>
<td> Palm OS
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Palm_OS_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Palm OS Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Pinball" title="Pinball">PBL</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PBL.png" class="image"><img alt="Platform - PBL.png" src="/Wiki/images/thumb/0/0f/Platform_-_PBL.png/32px-Platform_-_PBL.png" width="32" height="32" srcset="/Wiki/images/thumb/0/0f/Platform_-_PBL.png/48px-Platform_-_PBL.png 1.5x, /Wiki/images/thumb/0/0f/Platform_-_PBL.png/64px-Platform_-_PBL.png 2x"></a>
</td>
<td> Pinball
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Pinball_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Pinball Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Nintendo_Entertainment_System#PlayChoice-10" title="Nintendo Entertainment System">PC10</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PC10.png" class="image"><img alt="Platform - PC10.png" src="/Wiki/images/thumb/6/6e/Platform_-_PC10.png/32px-Platform_-_PC10.png" width="32" height="32" srcset="/Wiki/images/thumb/6/6e/Platform_-_PC10.png/48px-Platform_-_PC10.png 1.5x, /Wiki/images/thumb/6/6e/Platform_-_PC10.png/64px-Platform_-_PC10.png 2x"></a>
</td>
<td> Nintendo PlayChoice-10
</td>
<td> 8
</td>
<td> <a href="/Wiki/index.php?title=Category:PlayChoice-10_Games" title="Category:PlayChoice-10 Games">Category</a>
</td>
<td> Only create a different page if the soundtrack differs.
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PC-8801&amp;action=edit&amp;redlink=1" class="new" title="PC-8801 (page does not exist)">PC88</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PC88.png" class="image"><img alt="Platform - PC88.png" src="/Wiki/images/thumb/e/e9/Platform_-_PC88.png/32px-Platform_-_PC88.png" width="32" height="32" srcset="/Wiki/images/thumb/e/e9/Platform_-_PC88.png/48px-Platform_-_PC88.png 1.5x, /Wiki/images/thumb/e/e9/Platform_-_PC88.png/64px-Platform_-_PC88.png 2x"></a>
</td>
<td> NEC PC-8801
</td>
<td> 1
</td>
<td> <a href="/Wiki/index.php?title=Category:PC-8801_Games" title="Category:PC-8801 Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PC-9801" title="PC-9801">PC98</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PC98.png" class="image"><img alt="Platform - PC98.png" src="/Wiki/images/thumb/5/59/Platform_-_PC98.png/32px-Platform_-_PC98.png" width="32" height="32" srcset="/Wiki/images/thumb/5/59/Platform_-_PC98.png/48px-Platform_-_PC98.png 1.5x, /Wiki/images/thumb/5/59/Platform_-_PC98.png/64px-Platform_-_PC98.png 2x"></a>
</td>
<td> NEC PC-9801
</td>
<td> 7
</td>
<td> <a href="/Wiki/index.php?title=Category:PC-9801_Games" title="Category:PC-9801 Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PC_Boot_Loader" title="PC Boot Loader">PCB</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PCB.png" class="image"><img alt="Platform - PCB.png" src="/Wiki/images/thumb/e/e2/Platform_-_PCB.png/32px-Platform_-_PCB.png" width="32" height="32" srcset="/Wiki/images/thumb/e/e2/Platform_-_PCB.png/48px-Platform_-_PCB.png 1.5x, /Wiki/images/thumb/e/e2/Platform_-_PCB.png/64px-Platform_-_PCB.png 2x"></a>
</td>
<td> PC Boot Loader
</td>
<td> 3
</td>
<td> <a href="/Wiki/index.php?title=Category:PC_Boot_Loader_Games" title="Category:PC Boot Loader Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PC_Engine_CD-ROM&amp;action=edit&amp;redlink=1" class="new" title="PC Engine CD-ROM (page does not exist)">PCCD</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PCCD.png" class="image"><img alt="Platform - PCCD.png" src="/Wiki/images/thumb/f/fb/Platform_-_PCCD.png/32px-Platform_-_PCCD.png" width="32" height="32" srcset="/Wiki/images/thumb/f/fb/Platform_-_PCCD.png/48px-Platform_-_PCCD.png 1.5x, /Wiki/images/thumb/f/fb/Platform_-_PCCD.png/64px-Platform_-_PCCD.png 2x"></a>
</td>
<td> NEC PC Engine CD-ROM
</td>
<td> 1
</td>
<td> <a href="/Wiki/index.php?title=Category:PC_Engine_CD_Games" title="Category:PC Engine CD Games">Category</a>
</td>
<td> Use only for Non-American releases of TGCD.
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PC_Engine" class="mw-redirect" title="PC Engine">PCE</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PCE.png" class="image"><img alt="Platform - PCE.png" src="/Wiki/images/thumb/b/bb/Platform_-_PCE.png/32px-Platform_-_PCE.png" width="32" height="32" srcset="/Wiki/images/thumb/b/bb/Platform_-_PCE.png/48px-Platform_-_PCE.png 1.5x, /Wiki/images/thumb/b/bb/Platform_-_PCE.png/64px-Platform_-_PCE.png 2x"></a>
</td>
<td> NEC PC Engine
</td>
<td> 2
</td>
<td> <a href="/Wiki/index.php?title=Category:PC_Engine_Games" title="Category:PC Engine Games">Category</a>
</td>
<td> Use only for Non-American releases of TG16.
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PC_Engine_Duo&amp;action=edit&amp;redlink=1" class="new" title="PC Engine Duo (page does not exist)">PCED</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PCED.png" class="image"><img alt="Platform - PCED.png" src="/Wiki/images/thumb/b/ba/Platform_-_PCED.png/32px-Platform_-_PCED.png" width="32" height="32" srcset="/Wiki/images/thumb/b/ba/Platform_-_PCED.png/48px-Platform_-_PCED.png 1.5x, /Wiki/images/thumb/b/ba/Platform_-_PCED.png/64px-Platform_-_PCED.png 2x"></a>
</td>
<td> NEC PC Engine Duo
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:PC_Engine_Duo_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:PC Engine Duo Games (page does not exist)">Category</a>
</td>
<td> Use only for Non-American releases of TD.
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Pico" title="Pico">PICO</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PICO.png" class="image"><img alt="Platform - PICO.png" src="/Wiki/images/thumb/b/b1/Platform_-_PICO.png/32px-Platform_-_PICO.png" width="32" height="32" srcset="/Wiki/images/thumb/b/b1/Platform_-_PICO.png/48px-Platform_-_PICO.png 1.5x, /Wiki/images/thumb/b/b1/Platform_-_PICO.png/64px-Platform_-_PICO.png 2x"></a>
</td>
<td> Sega Pico (USA/EU)/Kids Computer Pico (JP)
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Pico_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Pico Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Pocket_PC&amp;action=edit&amp;redlink=1" class="new" title="Pocket PC (page does not exist)">PPC</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PPC.png" class="image"><img alt="Platform - PPC.png" src="/Wiki/images/thumb/3/33/Platform_-_PPC.png/32px-Platform_-_PPC.png" width="32" height="32" srcset="/Wiki/images/thumb/3/33/Platform_-_PPC.png/48px-Platform_-_PPC.png 1.5x, /Wiki/images/thumb/3/33/Platform_-_PPC.png/64px-Platform_-_PPC.png 2x"></a>
</td>
<td> Microsoft Pocket PC: 2000 or 2002.
</td>
<td> 1
</td>
<td> <a href="/Wiki/index.php?title=Category:Pocket_PC_Games" title="Category:Pocket PC Games">Category</a>
</td>
<td> Mention specific platforms it will run on.
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PlayStation&amp;action=edit&amp;redlink=1" class="new" title="PlayStation (page does not exist)">PS1</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PS1.png" class="image"><img alt="Platform - PS1.png" src="/Wiki/images/thumb/c/c7/Platform_-_PS1.png/32px-Platform_-_PS1.png" width="32" height="32" srcset="/Wiki/images/thumb/c/c7/Platform_-_PS1.png/48px-Platform_-_PS1.png 1.5x, /Wiki/images/thumb/c/c7/Platform_-_PS1.png/64px-Platform_-_PS1.png 2x"></a>
</td>
<td> Sony PlayStation 1
</td>
<td> 7
</td>
<td> <a href="/Wiki/index.php?title=Category:PlayStation_Games" title="Category:PlayStation Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PlayStation_2&amp;action=edit&amp;redlink=1" class="new" title="PlayStation 2 (page does not exist)">PS2</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PS2.png" class="image"><img alt="Platform - PS2.png" src="/Wiki/images/thumb/2/2e/Platform_-_PS2.png/32px-Platform_-_PS2.png" width="32" height="32" srcset="/Wiki/images/thumb/2/2e/Platform_-_PS2.png/48px-Platform_-_PS2.png 1.5x, /Wiki/images/thumb/2/2e/Platform_-_PS2.png/64px-Platform_-_PS2.png 2x"></a>
</td>
<td> Sony PlayStation 2
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:PlayStation_2_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:PlayStation 2 Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PlayStation_3&amp;action=edit&amp;redlink=1" class="new" title="PlayStation 3 (page does not exist)">PS3</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PS3.png" class="image"><img alt="Platform - PS3.png" src="/Wiki/images/thumb/7/75/Platform_-_PS3.png/32px-Platform_-_PS3.png" width="32" height="32" srcset="/Wiki/images/thumb/7/75/Platform_-_PS3.png/48px-Platform_-_PS3.png 1.5x, /Wiki/images/thumb/7/75/Platform_-_PS3.png/64px-Platform_-_PS3.png 2x"></a>
</td>
<td> Sony PlayStation 3
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:PlayStation_3_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:PlayStation 3 Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PlayStation_4&amp;action=edit&amp;redlink=1" class="new" title="PlayStation 4 (page does not exist)">PS4</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_PS4.png" class="image"><img alt="Platform - PS4.png" src="/Wiki/images/thumb/2/25/Platform_-_PS4.png/32px-Platform_-_PS4.png" width="32" height="32" srcset="/Wiki/images/thumb/2/25/Platform_-_PS4.png/48px-Platform_-_PS4.png 1.5x, /Wiki/images/thumb/2/25/Platform_-_PS4.png/64px-Platform_-_PS4.png 2x"></a>
</td>
<td> Sony PlayStation 4
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:PlayStation_4_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:PlayStation 4 Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=PlayStation_5&amp;action=edit&amp;redlink=1" class="new" title="PlayStation 5 (page does not exist)">PS5</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-
games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Switch&amp;action=edit&amp;redlink=1" class="new" title="Switch (page does not exist)">SW</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_SW.png" class="image"><img alt="Platform - SW.png" src="/Wiki/images/thumb/8/87/Platform_-_SW.png/32px-Platform_-_SW.png" width="32" height="32" srcset="/Wiki/images/thumb/8/87/Platform_-_SW.png/48px-Platform_-_SW.png 1.5x, /Wiki/images/thumb/8/87/Platform_-_SW.png/64px-Platform_-_SW.png 2x"></a>
</td>
<td> Nintendo Switch
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Switch_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Switch Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Symbian&amp;action=edit&amp;redlink=1" class="new" title="Symbian (page does not exist)">SYM</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_SYM.png" class="image"><img alt="Platform - SYM.png" src="/Wiki/images/thumb/a/a5/Platform_-_SYM.png/32px-Platform_-_SYM.png" width="32" height="32" srcset="/Wiki/images/thumb/a/a5/Platform_-_SYM.png/48px-Platform_-_SYM.png 1.5x, /Wiki/images/thumb/a/a5/Platform_-_SYM.png/64px-Platform_-_SYM.png 2x"></a>
</td>
<td> Symbian
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Symbian_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Symbian Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=TurboDuo&amp;action=edit&amp;redlink=1" class="new" title="TurboDuo (page does not exist)">TD</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_TD.png" class="image"><img alt="Platform - TD.png" src="/Wiki/images/thumb/1/11/Platform_-_TD.png/32px-Platform_-_TD.png" width="32" height="32" srcset="/Wiki/images/thumb/1/11/Platform_-_TD.png/48px-Platform_-_TD.png 1.5x, /Wiki/images/thumb/1/11/Platform_-_TD.png/64px-Platform_-_TD.png 2x"></a>
</td>
<td> NEC TurboDuo
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:Turbo_Duo_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:Turbo Duo Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=TurboGrafx-16" title="TurboGrafx-16">TG16</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_TG16.png" class="image"><img alt="Platform - TG16.png" src="/Wiki/images/thumb/4/4c/Platform_-_TG16.png/32px-Platform_-_TG16.png" width="32" height="32" srcset="/Wiki/images/thumb/4/4c/Platform_-_TG16.png/48px-Platform_-_TG16.png 1.5x, /Wiki/images/thumb/4/4c/Platform_-_TG16.png/64px-Platform_-_TG16.png 2x"></a>
</td>
<td> NEC TurboGrafx-16
</td>
<td> 4
</td>
<td> <a href="/Wiki/index.php?title=Category:TurboGrafx-16_Games" title="Category:TurboGrafx-16 Games">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=TurboGrafx_CD-ROM&amp;action=edit&amp;redlink=1" class="new" title="TurboGrafx CD-ROM (page does not exist)">TGCD</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_TGCD.png" class="image"><img alt="Platform - TGCD.png" src="/Wiki/images/thumb/a/aa/Platform_-_TGCD.png/32px-Platform_-_TGCD.png" width="32" height="32" srcset="/Wiki/images/thumb/a/aa/Platform_-_TGCD.png/48px-Platform_-_TGCD.png 1.5x, /Wiki/images/thumb/a/aa/Platform_-_TGCD.png/64px-Platform_-_TGCD.png 2x"></a>
</td>
<td> NEC TurboGrafx CD-ROM
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:TurboGrafx_CD_Games&amp;action=edit&amp;redlink=1" class="new" title="Category:TurboGrafx CD Games (page does not exist)">Category</a>
</td>
<td>
</td></tr>
<tr>
<td> <a href="/Wiki/index.php?title=Thomson_MO&amp;action=edit&amp;redlink=1" class="new" title="Thomson MO (page does not exist)">TMO</a>
</td>
<td style="text-align:center;"> <a href="/Wiki/index.php?title=File:Platform_-_TMO.png" class="image"><img alt="Platform - TMO.png" src="/Wiki/images/thumb/d/d5/Platform_-_TMO.png/32px-Platform_-_TMO.png" width="32" height="32" srcset="/Wiki/images/thumb/d/d5/Platform_-_TMO.png/48px-Platform_-_TMO.png 1.5x, /Wiki/images/thumb/d/d5/Platform_-_TMO.png/64px-Platform_-_TMO.png 2x"></a>
</td>
<td> Thomson MO
</td>
<td> 0
</td>
<td> <a href="/Wiki/index.php?title=Category:
<td> <a href="/Wiki/index.php?title=Category:ZX_Spectrum_Games" title="Category:ZX Spectrum Games">Category</a>
</td>
<td>
</td></tr></tbody></table>
'''

# %%
table1 = pd.read_html(table_a_n)[0]
table2 = pd.read_html(table_o_z)[0]
table = table1.append(table2, ignore_index=True)
table
# Out:
#     Abbr.  Icon            Platform Name  Count  Category Notes
# 0     32X   NaN                 Sega 32X      1  Category   NaN
# 1     3DO   NaN          3DO Multiplayer      3  Category   NaN
# 2     3DS   NaN             Nintendo 3DS      0  Category   NaN
# 3      A2   NaN                 Apple II      2  Category   NaN
# 4     A26   NaN               Atari 2600     56  Category   NaN
# ..    ...   ...                      ...    ...       ...   ...
# 130  XONE   NaN       Microsoft Xbox One      0  Category   NaN
# 131   XSX   NaN  Microsoft Xbox Series X      0  Category   NaN
# 132  ZEBO   NaN              Zeebo Zeebo      0  Category   NaN
# 133   ZOD   NaN           Tapwave Zodiac      0  Category   NaN
# 134   ZXS   NaN     Sinclair ZX Spectrum     12  Category   NaN
#
# [135 rows x 6 columns]

# %%
from functools import cache
abbr_name_dict = dict(zip(table['Abbr.'],table['Platform Name']))
@cache
def get_full_platform_name(abbr):
    if abbr in abbr_name_dict:
        return abbr_name_dict[abbr]
    return 'Неизвестно'

# %% [markdown]
# применим данную функцию, создав новый столбец с полным названием платформы

# %%
df.reset_index(drop=True, inplace=True)
df.loc[:,'full_platform'] = df['platform'].apply(get_full_platform_name)

# %% [markdown]
# я пробовал разными способами избавиться от данной ошибки, но так и не получилось.
# также иногда помогает
# `df.reset_index(drop=True, inplace=True)`
# но нужно несколько раз ячейку запустить, чтобы пропало предупреждение...
#
# Посмотрим сколько раз встречается неизвестная платформа

# %%
df['full_platform'].value_counts()
# Out:
# Неизвестно                             7424
# Sony PlayStation 2                     2161
# Sony PlayStation 3                     1331
# Microsoft Xbox 360                     1262
# Sony PlayStation Portable              1209
# Nintendo Game Boy Advance               822
# Nintendo GameCube                       556
# Nintendo 3DS                            520
# Sony PlayStation 4                      392
# Nintendo 64                             319
# Super Nintendo Entertainment System     239
# Sega Saturn                             173
# Nintendo Game Boy                        98
# Nintendo Entertainment System            98
# Sega Dreamcast                           52
# Sega Genesis                             27
# SNK Neo Geo                              12
# Sega CD                                   6
# Bandai Wonderswan                         6
# 3DO Multiplayer                           3
# NEC TurboGrafx-16                         2
# ...

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера 💡</b>
#
# Не совсем понял, в чем была необходимость такого

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Мне показалось, что полное название платформ нагляднее, а вручную не хотелось вбивать
# </div>

# %% [markdown]
# 7424 - это очень много, посмотрим, какие платформы были помечены как неизвестные

# %%
df[df['full_platform'] == 'Неизвестно']['platform'].value_counts()
# Out:
# DS      2151
# Wii     1320
# PS      1197
# PC       974
# XB       824
# PSV      430
# XOne     247
# WiiU     147
# 2600     133
# PCFX       1
# Name: platform, dtype: int64

# %%
df.loc[df['platform'] == 'DS','full_platform'] = 'Nintendo DS'

# %%
df.loc[df['platform'] == '2600','full_platform'] = 'Atari 2600'

# %%
df.loc[df['platform'] == 'PS','full_platform'] = 'Sony PlayStation'

# %%
df.loc[df['platform'] == 'PC','full_platform'] = 'Personal Computer'

# %%
df.loc[df['platform'] == 'XB','full_platform'] = 'Microsoft Xbox'

# %%
df.loc[df['platform'] == 'PSV','full_platform'] = 'PlayStation Vita'

# %%
df.loc[df['platform'] == 'XOne','full_platform'] = 'Microsoft Xbox One'

# %%
df.loc[df['platform'] == 'WiiU','full_platform'] = 'Nintendo Wii U'

# %%
df.loc[df['platform'] == 'Wii','full_platform'] = 'Nintendo Wii'

# %%
df.loc[df['platform'] == '2600','full_platform'] = 'Atari 2600'

# %%
df = df.drop(df[df.platform == 'PCFX'].index)

# %% [markdown]
# PC-FX очень древняя https://ru.wikipedia.org/wiki/PC-FX и на нее всего 1 игра, поэтому не будем учитывать

# %%
df['full_platform'].value_counts()
# Out:
# Sony PlayStation 2                     2161
# Nintendo DS                            2151
# Sony PlayStation 3                     1331
# Nintendo Wii                           1320
# Microsoft Xbox 360                     1262
# Sony PlayStation Portable              1209
# Sony PlayStation                       1197
# Personal Computer                       974
# Microsoft Xbox                          824
# Nintendo Game Boy Advance               822
# Nintendo GameCube                       556
# Nintendo 3DS                            520
# PlayStation Vita                        430
# Sony PlayStation 4                      392
# Nintendo 64                             319
# Microsoft Xbox One                      247
# Super Nintendo Entertainment System     239
# Sega Saturn                             173
# Nintendo Wii U                          147
# Atari 2600                              133
# Nintendo Entertainment System            98
# ...

# %% [markdown]
# удалим игры, которые представлены в небольшом количестве меньше 100

# %%
100/len(df)
# Out:
# 0.005983724269985639

# %% [markdown]
# это меньше 1% выборки

# %%
value_counts = df['full_platform'].value_counts()

# Select the values where the count is less than 3 (or 5 if you like)
to_remove = value_counts[value_counts <= 100].index

# Keep rows where the city column is not in to_remove
df = df[~df.full_platform.isin(to_remove)]

# %% [markdown]
# ##### год выпуска

# %%
df['year_of_release'].value_counts().sort_values()
# Out:
# 1984       1
# 1989       2
# 1986       2
# 1985       3
# 1988       3
# 1990       4
# 1987       6
# 1980       9
# 1983      11
# 1991      24
# 1992      26
# 1982      36
# 1981      46
# 1993      46
# 1994      95
# 1995     207
# 1996     254
# 0        268
# 1997     281
# 2000     311
# 1999     311
# 1998     364
# 2001     462
# 2016     502
# 2013     544
# 2014     581
# 2015     606
# 2012     653
# 2004     762
# 2003     775
# 2002     828
# 2005     939
# 2006    1006
# 2011    1136
# 2007    1196
# 2010    1255
# 2009    1426
# 2008    1426
# Name: year_of_release, dtype: int64

# %% [markdown]
# для 268 игр не указан год, посмотрим, что это за игры

# %%
print('Игр, где не указан год',round(100*len(df[df['year_of_release'] == 0])/len(df),1),'% от общей выборки')
# Out:
# Игр, где не указан год 1.6 % от общей выборки

# %% [markdown]
# вообще, можно найти информацию по году выпуска данных игр, но поскольку таких игр мало, меньше 2%, то просто удалим данные записи

# %%
df = df[df['year_of_release'] != 0]

# %% [markdown]
# ##### Жанр

# %%
df['genre'].value_counts()
# Out:
# Action          3282
# Sports          2269
# Misc            1708
# Role-Playing    1436
# Shooter         1283
# Adventure       1272
# Racing          1212
# Simulation       850
# Platform         821
# Fighting         805
# Strategy         662
# Puzzle           539
# Name: genre, dtype: int64

# %%
df['genre'].sort_values().unique()
# Out:
# array(['Action', 'Adventure', 'Fighting', 'Misc', 'Platform', 'Puzzle',
#        'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports',
#        'Strategy'], dtype=object)

# %% [markdown]
# Похоже, что с жанрами все хорошо

# %% [markdown]
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
df['all_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 </b>
#
# Более изящная конструкция
#
# data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Спасибо, пригодится
# </div>

# %%
df[df['all_sales'] == 0]
# Out:
#                                                    name platform  \
# 16674                                  G1 Jockey 4 2008      PS3
# 16707  SCORE International Baja 1000: The Official Game      PS2
#
#        year_of_release   genre  na_sales  eu_sales  jp_sales  other_sales  \
# 16674             2008  Sports       0.0       0.0       0.0          0.0
# 16707             2008  Racing       0.0       0.0       0.0          0.0
#
#        critic_score  user_score rating       full_platform  all_sales
# 16674           NaN         NaN    NaN  Sony PlayStation 3        0.0
# 16707           NaN         NaN    NaN  Sony PlayStation 2        0.0

# %% [markdown]
# Всего 2 записи, у которых отсутствует информация о продажах. удалим их

# %%
df = df[df['all_sales'] > 0]

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Не выполнен пункт: "Опишите причины, которые могли привести к пропускам"

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# В этом датафрейме могут возникать пропуски по разным причинам:
#
# Недоступность данных: в некоторых случаях данные могут быть недоступны из-за отсутствия информации или ошибок в процессе сбора данных.
#
# Отсутствие значения: в некоторых случаях значение не может быть представлено или отсутствует, например, если критик не оценил игру или не было ответа от пользователя.
#
# Логические ошибки: в редких случаях пропуски могут возникнуть из-за ошибок в коде или неожиданного поведения данных, например, если игра была выпущена до того, как платформа стала доступной, или если данные были удалены из-за ошибок в обработке данных.
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 Вторая итерация </b>
#
# Согласен с причинами

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# В столбце rating необходимы значения-заглушки. Позже увидишь, почему это важно

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Я же могу заполнить строкой "неизвестно"?
# </div>

# %%
df['rating'].fillna('неизвестно', inplace=True)

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 Вторая итерация </b>
#
# Да, вполне

# %% [markdown]
# ## Шаг. Проведите исследовательский анализ данных

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
(
    df.plot(y='year_of_release', kind='hist', grid=True, figsize=(12, 5), bins=36)
)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Данных до 1995 года очень мало, поэтому мы не будем их учитывать при исследовании

# %%
df = df.query('year_of_release > 1995')
(
    df.plot(y='year_of_release', kind='hist', grid=True, figsize=(12, 5), bins=(2016-1995))
)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера 💡</b>
#
# Не забывай подписывать графики, это важно

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
df.pivot_table(index='full_platform', values='all_sales', aggfunc='sum' ).sort_values(by='all_sales',ascending=False)
# Out:
#                                      all_sales
# full_platform
# Sony PlayStation 2                     1233.56
# Microsoft Xbox 360                      961.24
# Sony PlayStation 3                      931.34
# Nintendo Wii                            891.18
# Nintendo DS                             802.76
# Sony PlayStation                        685.59
# Sony PlayStation 4                      314.14
# Nintendo Game Boy Advance               312.88
# Sony PlayStation Portable               289.53
# Nintendo 3DS                            257.81
# Microsoft Xbox                          251.57
# Personal Computer                       235.57
# Nintendo 64                             218.01
# Nintendo GameCube                       196.73
# Microsoft Xbox One                      159.32
# Nintendo Wii U                           82.19
# PlayStation Vita                         53.81
# Sega Saturn                              18.37
# Super Nintendo Entertainment System      17.39

# %%
import matplotlib.pyplot as plt

df_by_platform = df.pivot_table(index='year_of_release', values='all_sales', aggfunc='sum' )
df_by_platform.sort_index()
for platform in df['full_platform'].unique():
    ax = (
        df
        .query('full_platform == @platform')
        .pivot_table(index='year_of_release', values='all_sales', aggfunc='sum' )
        .sort_index()
        .plot(y='all_sales', xlim=(1995,2016), title=platform)
    )
    
    ax.locator_params(integer=True)
    ax.set_xticks(range(1995,2017))
    ax.set_xticklabels([item for item in range(1995,2017)], rotation=90)
    plt.show()

# %% [markdown]
# Видим, что популярность каждой платформы сохраняется на протяжении около 4 лет

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.

# %% [markdown]
# возьмем данные за последние 3 года, так как нет смысла делать прогноз для платформ, которые уже как давно не популярны

# %%
df = df.query('year_of_release >= 2014')

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 </b>
#
# Согласен с выбранным сроком для прогнозирования

# %% [markdown]
# Посмотрим, какие платформы лидируют по продажам

# %%
platform_sales = df.pivot_table(index='full_platform', values='all_sales', aggfunc='sum' ).sort_values(by='all_sales',ascending=False)
platform_sales.columns = ['sales']
platform_sales
# Out:
#                             sales
# full_platform
# Sony PlayStation 4         288.15
# Microsoft Xbox One         140.36
# Nintendo 3DS                86.68
# Sony PlayStation 3          68.18
# Microsoft Xbox 360          48.22
# Nintendo Wii U              42.98
# Personal Computer           27.05
# PlayStation Vita            22.40
# Nintendo Wii                 5.07
# Sony PlayStation Portable    0.36

# %% [markdown]
# Лидируют по продажам Sony PlayStation 4, Microsoft Xbox One, Nintendo 3DS. Построим для них графики "ящик с усами"

# %%
top_three_platforms = platform_sales.nlargest(3,'sales').index.values.tolist()
top_three_platforms
# Out:
# ['Sony PlayStation 4', 'Microsoft Xbox One', 'Nintendo 3DS']

# %% [markdown]
# Построим boxplot для столбца "all_sales" по каждой из трех платформ, которые имеют наибольшее количество продаж игр.

# %%
df[df['full_platform'].isin(top_three_platforms)].boxplot(column=['all_sales'], by='full_platform')
# Out:
# <AxesSubplot:title={'center':'all_sales'}, xlabel='full_platform'>

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.xlim(0, 2)
ax = sns.boxplot(y="full_platform", x="all_sales", data=df[df.full_platform.isin(top_three_platforms)], orient="h")
plt.show()

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 </b>
#
# Боксплот построен верно

# %%
cols = ['all_sales' ,'critic_score','user_score']
sns_plot = sns.pairplot(df.query('full_platform == @top_three_platforms[0]')[cols])

# %%
cols = ['all_sales' ,'critic_score','user_score']
sns_plot = sns.pairplot(df.query('full_platform == @top_three_platforms[1]')[cols])

# %%
cols = ['all_sales' ,'critic_score','user_score']
sns_plot = sns.pairplot(df.query('full_platform == @top_three_platforms[2]')[cols])

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Нет подсчета корреляции

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Добавил для PlayStation4
# </div>

# %%
# выбираем платформу PS4
platform = 'PS4'

# отфильтровываем данные по платформе и удаляем строки с пропущенными значениями
df_platform = df[df['platform'] == platform].dropna(subset=['critic_score', 'user_score', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales'])

# строим диаграмму рассеяния для отзывов критиков и продаж
df_platform.plot(x='critic_score', y='na_sales', kind='scatter', alpha=0.5)

# рассчитываем коэффициент корреляции между отзывами критиков и продажами
correlation_critic_sales = df_platform['critic_score'].corr(df_platform['na_sales'])
print('Коэффициент корреляции между отзывами критиков и продажами:', correlation_critic_sales)

# строим диаграмму рассеяния для отзывов пользователей и продаж
df_platform.plot(x='user_score', y='na_sales', kind='scatter', alpha=0.5)

# рассчитываем коэффициент корреляции между отзывами пользователей и продажами
correlation_user_sales = df_platform['user_score'].corr(df_platform['na_sales'])
print('Коэффициент корреляции между отзывами пользователей и продажами:', correlation_user_sales)
# Out:
# Коэффициент корреляции между отзывами критиков и продажами: 0.41077347688982896
# Коэффициент корреляции между отзывами пользователей и продажами: -0.01884676265305296

# %%
platform_genre_sales = df.pivot_table(
                        index='full_platform', 
                        columns='genre', 
                        values='all_sales', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(platform_genre_sales, annot=True, fmt=".1f", linewidths=.5)
# Out:
# <AxesSubplot:xlabel='genre', ylabel='full_platform'>

# %%
platform_genre_sales = df.pivot_table(
                        index='rating', 
                        columns='genre', 
                        values='all_sales', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(platform_genre_sales, annot=True, fmt=".1f", linewidths=.5)
# Out:
# <AxesSubplot:xlabel='genre', ylabel='rating'>

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Общие продажи/кол-во продаж - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть медианные продажи. Да и heatmap не очень хороший выбор для такой задачи

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Ты прав, медианные продажи более точно отражают, какой жанр игр приносит стабильный доход. Heatmap может быть полезна для общего представления о продажах игр в различных жанрах, но не может использоваться в качестве основного инструмента для анализа прибыльности жанров. Для более точного анализа можно использовать boxplot, который позволяет сравнить медианные значения и разброс продаж между жанрами.
# </div>

# %%
import seaborn as sns

# создаем новый DataFrame с медианными продажами по жанрам
median_sales_by_genre = df.groupby('genre')['all_sales'].median().sort_values(ascending=False).reset_index()

# задаем порядок отображения жанров на графике
genre_order = median_sales_by_genre['genre']

# устанавливаем название графика и осей
plt.figure(figsize=(12,9))
plt.title('Boxplot по жанрам и медианным продажам')
sns.boxplot(x='genre', y='all_sales', data=df)
plt.ylim(0, 4)
plt.show()

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# С пункта 3.3 нет никаких комментариев, промежуточных выводов, непонятно, что ты делаешь

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Добавил
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 Вторая итерация </b>
#
# Теперь все супер)

# %% [markdown]
# ## Шаг. Составьте портрет пользователя каждого региона

# %% [markdown]
# ### Самые популярные платформы (топ-5). Опишите различия в долях продаж.

# %%
na_platform_sales = df.groupby('platform')['na_sales'].sum().sort_values(ascending=False)[:5]
plt.figure(figsize=(12,6))
sns.barplot(x=na_platform_sales.index, y=na_platform_sales.values, palette='magma')
plt.title('Самые популярные платформы в США')
plt.xlabel('Платформа')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %%
# Суммарные продажи по платформам в Европе
eu_platform_sales = df.groupby('platform')['eu_sales'].sum().sort_values(ascending=False)[:5]
plt.figure(figsize=(12,6))
sns.barplot(x=eu_platform_sales.index, y=eu_platform_sales.values, palette='magma')
plt.title('Самые популярные платформы в Европе')
plt.xlabel('Платформа')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %%
# Суммарные продажи по платформам в Японии
jp_platform_sales = df.groupby('platform')['jp_sales'].sum().sort_values(ascending=False)[:5]
plt.figure(figsize=(12,6))
sns.barplot(x=jp_platform_sales.index, y=jp_platform_sales.values, palette='magma')
plt.title('Самые популярные платформы в Японии')
plt.xlabel('Платформа')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %% [markdown]
# ### Самые популярные жанры (топ-5). Поясните разницу.

# %%
# Суммарные продажи по жанрам в Северной Америке
na_genre_sales = df.groupby('genre')['na_sales'].sum().sort_values(ascending=False)[:5]
plt.figure(figsize=(12,6))
sns.barplot(x=na_genre_sales.index, y=na_genre_sales.values, palette='magma')
plt.title('Самые популярные жанры (топ-5) в Северной Америке')
plt.xlabel('Жанр')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %%
# Суммарные продажи по жанрам в Европе
eu_genre_sales = df.groupby('genre')['eu_sales'].sum().sort_values(ascending=False)[:5]
plt.figure(figsize=(12,6))
sns.barplot(x=eu_genre_sales.index, y=eu_genre_sales.values, palette='magma')
plt.title('Самые популярные жанры (топ-5) в Европе')
plt.xlabel('Жанр')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %%
jp_genre_sales = df.groupby('genre')['jp_sales'].sum().sort_values(ascending=False)[:5]
plt.figure(figsize=(12,6))
sns.barplot(x=jp_genre_sales.index, y=jp_genre_sales.values, palette='magma')
plt.title('Самые популярные жанры (топ-5) в Японии')
plt.xlabel('Жанр')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %% [markdown]
# Интересно, что в каждом регионе лидирует свой жанр

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# Чтобы определить, как рейтинг ESRB влияет на продажи в отдельных регионах, мы можем сгруппировать данные по рейтингу и посчитать суммарные продажи для каждой категории рейтинга в каждом регионе:

# %%
# Суммарные продажи по рейтингу ESRB в Северной Америке
na_rating_sales = df.groupby('rating')['na_sales'].sum()
plt.figure(figsize=(12,6))
sns.barplot(x=na_rating_sales.index, y=na_rating_sales.values, palette='magma')
plt.title('Влияние рейтинга ESRB на продажи в Северной Америке')
plt.xlabel('Рейтинг ESRB')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %%
# Суммарные продажи по рейтингу ESRB в Европе
eu_rating_sales = df.groupby('rating')['eu_sales'].sum()
plt.figure(figsize=(12,6))
sns.barplot(x=eu_rating_sales.index, y=eu_rating_sales.values, palette='magma')
plt.title('Влияние рейтинга ESRB на продажи в Европе')
plt.xlabel('Рейтинг ESRB')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %%
# Суммарные продажи по рейтингу ESRB в Японии
jp_rating_sales = df.groupby('rating')['jp_sales'].sum()
plt.figure(figsize=(12,6))
sns.barplot(x=jp_rating_sales.index, y=jp_rating_sales.values, palette='magma')
plt.title('Влияние рейтинга ESRB на продажи в Японии')
plt.xlabel('Рейтинг ESRB')
plt.ylabel('Всего продаж (млн)')
plt.show()

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах. Используй значения-заглушки.
#
# Иногда пропуск сам по себе является ценной информацией. Например, нужно держать в уме, для каких стран создавалась система ESRB? Будут ли стараться авторы игр для локального рынка других стран получить рейтинг ESRB?

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Да, действительно. Когда неизвестный рейтинг учитывается в анализе, то получается другая картина
# </div>

# %% [markdown]
# **Видим, что рейтинг ESRB влияет на продажу игры сильнее всего в Северной Америке**

# %% [markdown]
# ## Шаг. Проверьте гипотезы

# %% [markdown]
# Для проверки гипотез мы будем использовать статистический метод гипотезы о равенстве средних двух генеральных совокупностей (для первой гипотезы) и о разности средних двух генеральных совокупностей (для второй гипотезы).
# Мы будем использовать двусторонний критерий, так как мы хотим узнать, отличаются ли средние значения между сравниваемыми группами в любом направлении.
#
# Пороговое значение alpha зададим равным 0.05.
#
# Нулевая гипотеза (H0) для первой гипотезы будет звучать так: средние пользовательские рейтинги платформ Xbox One и PC равны.
# Альтернативная гипотеза (H1): средние пользовательские рейтинги платформ Xbox One и PC отличаются.

# %%
xbox_one_user_ratings = df[df['platform'] == 'XOne']['user_score'].dropna()
pc_user_ratings = df[df['platform'] == 'PC']['user_score'].dropna()

# %%
from scipy import stats

# %% [markdown]
# Для проверки первой гипотезы мы будем использовать t-тест Стьюдента для двух выборок с равными дисперсиями, так как мы хотим сравнить средние значения двух генеральных совокупностей (средние пользовательские рейтинги платформ Xbox One и PC).

# %%
alpha = 0.05
results = stats.ttest_ind(xbox_one_user_ratings, pc_user_ratings, equal_var=True)
print('p-value:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# p-value: 0.10450507919348415
# Не удалось отвергнуть нулевую гипотезу

# %% [markdown]
# Для проверки второй гипотезы (о различии средних пользовательских рейтингов для жанров Action и Sports), также необходимо сформировать две выборки из данных исходного датафрейма:

# %%
action_user_ratings = df[df['genre'] == 'Action']['user_score'].dropna()
sports_user_ratings = df[df['genre'] == 'Sports']['user_score'].dropna()

# %% [markdown]
# Нулевая гипотеза (H0) для второй гипотезы будет звучать так: средние пользовательские рейтинги жанров Action и Sports равны.
# Альтернативная гипотеза (H1): средние пользовательские рейтинги жанров Action и Sports отличаются.

# %% [markdown]
# Для проверки второй гипотезы мы будем использовать t-тест Стьюдента для двух выборок с не равными дисперсиями, так как мы хотим сравнить средние значения двух генеральных совокупностей (средние пользовательские рейтинги жанров Action и Sports), но дисперсии этих генеральных совокупностей могут быть не равны.

# %%
alpha = 0.05
results = stats.ttest_ind(action_user_ratings, sports_user_ratings, equal_var=False)
print('p-value:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# p-value: 1.1825550382644557e-14
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера 💡</b>
#
# "Для проверки гипотез мы будем использовать статистический метод гипотезы о равенстве средних двух генеральных совокупностей (для первой гипотезы) и о разности средних двух генеральных совокупностей (для второй гипотезы)."
#
# Нет, статистический критерий (тест) один и тот же - тест Стьюдента. Подробнее: https://habr.com/en/company/uchi_ru/blog/500918/

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Понял. Спасибо за ссылку, ознакомлюсь!
# </div>

# %% [markdown]
# ## Шаг. Напишите общий вывод

# %% [markdown]
# В результате проведенного анализа данных о продажах компьютерных игр с 1984 по 2016 годы (ограничились только актуальными данными за последние 3 года), были выявлены следующие закономерности:
#
# Самые популярные платформы за все время - PlayStation 2, Xbox 360, PlayStation 3, Wii, Nintendo DS. Однако, в последние годы популярность у них снижается, а на смену приходят PlayStation 4 и Xbox One.
#
# Самые популярные жанры - Action, Shooter, Role-Playing. Однако, в разных регионах предпочтения могут различаться.
#
# Рейтинг ESRB может влиять на продажи игр в отдельных регионах.
#
# Проверены гипотезы о равенстве средних пользовательских рейтингов для платформ Xbox One и PC и о различии средних пользовательских рейтингов для жанров Action и Sports. В первом случае нулевую гипотезу отвергнуть не удалось, а во втором - была отвергнута.
#
# Таким образом, анализ данных о продажах компьютерных игр позволил выявить некоторые закономерности, которые могут помочь разработчикам и издателям игр определить, какие платформы и жанры стоит выбирать для своих проектов. Также, проведенные статистические тесты позволяют более точно определить влияние различных факторов на продажи игр.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍</b>
#
# Хороший общий вывод!

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Отличный проект, тобою проделана большая работа, ты молодец!
#
# По коду вопросов практически нет, в том числе у тебя хорошие графики и визуализация имеющихся данных. Каждый пункт у тебя достаточно хороший, но в каждом из них есть по ошибке. Тем не менее, я уверен, что ты довольно легко с ними сможешь справиться
#
# Что обязательно стоит доработать: использовать значения-заглушки в пункте составления портретов пользователей / подготовки данных; посмотреть иначе на самые популярные / прибыльные жанры; добавить подсчет корреляции; добавить комментарии/рассуждения и промежуточные выводы к проекту; добавить вступление в проект
#
# Также я оставил несколько желтых комментариев. Думаю, и они будут тебе полезны.
#
# Буду ждать доработок :) Удачи!

# %% [markdown]
# <div class="alert-info">
# <b>Комментарий студента 📚 </b>
#
# Постарался все исправить. Спасибо за проверку и за полезные ссылки 😊
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера 👍 Вторая итерация </b>
#
# Все ошибки исправлены, проект стал еще лучше, принимаю. Успехов в дальнейшей учебе!

# %% [markdown]
# # Подсказки

# %% [markdown]
# <ul><li><em>Name</em> — название игры</li><li><em>Platform</em> — платформа</li><li><em>Year_of_Release</em> — год выпуска</li><li><em>Genre</em> — жанр игры</li><li><em>NA_sales —</em> продажи в Северной Америке (миллионы проданных копий)</li><li><em>EU_sales</em> — продажи в Европе (миллионы проданных копий)</li><li><em>JP_sales</em> — продажи в Японии (миллионы проданных копий)</li><li><em>Other_sales —</em> продажи в других странах (миллионы проданных копий)</li><li><em>Critic_Score</em> — оценка критиков (максимум 100)</li><li><em>User_Score</em> — оценка пользователей (максимум 10)</li><li><em>Rating</em> — рейтинг от организации <em>ESRB</em> (англ. <em>Entertainment Software Rating Board).</em> Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.</li></ul>
